# %% [markdown]
# <a href="https://colab.research.google.com/github/Eason0227/Aidea-AOI-defects-detection/blob/main/AOI_MobileNetV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
import warnings
warnings.filterwarnings('ignore')
from google.colab import drive
drive.mount('/content/drive')
from sklearn.model_selection import train_test_split

df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/AOI/aoi/train.csv')
# Out:
# Mounted at /content/drive

# %%
df.head()
# Out:
#                 ID  Label
# 0  train_00000.png      0
# 1  train_00001.png      1
# 2  train_00002.png      1
# 3  train_00003.png      5
# 4  train_00004.png      5

# %% [markdown]
# ## Check image imformation

# %%
TRAIN_IMAGEPATH = '/content/drive/My Drive/Colab Notebooks/AOI/aoi/train_images/'
img = cv2.imread( os.path.join( TRAIN_IMAGEPATH, df.loc[0,"ID"]))
print(f"image shape: {img.shape}")
print(f"data type: {img.dtype}")
print(f"min: {img.min()}, max: {img.max()}")
plt.imshow(img)
plt.show()
# Out:
# image shape: (512, 512, 3)
# data type: uint8
# min: 109, max: 255

# %% [markdown]
# ## Label : Defect type
# ---
# 0:normal
# 1:void
# 2:horizontal defect
# 3:vertical defect
# 4:edge defect
# 5:particle

# %%
normal_list = df[df["Label"]==0]["ID"].values
void_list = df[df["Label"]==1]["ID"].values
horizontal_defect_list = df[df["Label"]==2]["ID"].values
vertical_defect_list = df[df["Label"]==3]["ID"].values
edge_defect_list = df[df["Label"]==4]["ID"].values
particle_list = df[df["Label"]==5]["ID"].values
label = [normal_list,void_list,horizontal_defect_list,vertical_defect_list,edge_defect_list,particle_list]
defect = ['normal','void','horizontal defect','vertical defect','edge defect','particle']

# %%
plt.figure(figsize=(12, 6))
for i in range(6):
  plt.subplot(2, 3, i+1)
  img = cv2.imread( os.path.join( TRAIN_IMAGEPATH, label[i][i]),0)
  plt.imshow(img,cmap='gray')
  plt.axis("off")
  plt.title(defect[i])
plt.suptitle(f"Variety of samples", fontsize=12)
plt.show()

# %% [markdown]
# ## Check the distribution of label

# %%
from matplotlib import gridspec
fig = plt.figure(figsize=(20, 4.5))
gs = gridspec.GridSpec(1, 2, width_ratios=[1, 2.5])
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])

uni_pattern = np.unique( df['Label'], return_counts=True)

ax1.pie( uni_pattern[1], labels = uni_pattern[0], autopct='%1.1f%%', shadow=True, startangle=140)
color_set = ['tab:blue','tab:orange','tab:green','tab:red','tab:purple','tab:brown']

ax2.bar( uni_pattern[0] ,uni_pattern[1]/ df.shape[0], color = color_set ,align='center', alpha=0.9)
ax2.set_title("failure type frequency")
ax2.set_ylabel("% of pattern wafers")
plt.show()

# %% [markdown]
# ## Training and validation data

# %%
train,valid= train_test_split(df,test_size=0.2,random_state=42)

train.reset_index(drop=True,inplace=True)
valid.reset_index(drop=True,inplace=True)

train["Label"]=train["Label"].astype("str")
valid["Label"]=valid["Label"].astype("str")

# %% [markdown]
# ## Dealing with data imbalance
# Add a larger penalty value weight to the category with a small number of samples

# %%
from sklearn.utils.class_weight import compute_class_weight

unique, counts = np.unique( train["Label"].values , return_counts=True)
print("unique ", unique)
print("counts: ", counts)

class_weights = compute_class_weight(class_weight='balanced', classes= unique, y = train["Label"])
print(class_weights)
# Out:
# unique  ['0' '1' '2' '3' '4' '5']
# counts:  [537 401  77 310 195 502]
# [0.62756052 0.840399   4.37662338 1.08709677 1.72820513 0.67131474]

# %% [markdown]
# ## Data Augmentation

# %%
import tensorflow as tf
from tensorflow import keras
from keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rotation_range=15,
         horizontal_flip = False,
         vertical_flip = False,
         width_shift_range = 0.05,
         height_shift_range = 0.05,
         preprocessing_function = preprocess_input )

valid_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)

# %% [markdown]
# ## Input training and validation pictures
# Using flow_from_dataframe does not need to mark the pictures, just place them all in one folder, but it is necessary to make a DataFrame, which must contain the name and label of the picture

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# img_shape should be set according to the input limit of the model
img_shape = (224,224)
batch_size = 16

train_generator = train_datagen.flow_from_dataframe(dataframe=train,
                            directory= TRAIN_IMAGEPATH,
                            x_col="ID",
                            y_col="Label",
                            target_size=img_shape,
                            batch_size=batch_size,
                            class_mode='categorical',
                            shuffle=True)

valid_generator = valid_datagen.flow_from_dataframe(dataframe=valid,
                            directory= TRAIN_IMAGEPATH,
                            x_col="ID",
                            y_col="Label",
                            target_size=img_shape,
                            batch_size=batch_size,
                            class_mode='categorical',
                            shuffle=True)
# Out:
# Found 2022 validated image filenames belonging to 6 classes.
# Found 506 validated image filenames belonging to 6 classes.

# %% [markdown]
# ## Set the number of pictures for each epoch training

# %%
steps_per_epoch_train = len(train_generator)
steps_per_epoch_val= len(valid_generator)
steps_per_epoch_train
# Out:
# 127

# %% [markdown]
# # Bulid model

# %%
from tensorflow.keras.applications import MobileNetV2
from keras.layers import Input, Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from keras.models import Model

# Load the pre-trained model Xception, apply the weight of imagenet
model = MobileNetV2(include_top=False, weights='imagenet', input_tensor=Input(shape=(224,224,3)))

# Define the output layer, update the number of categories of the output
x = model.output
x = GlobalAveragePooling2D()(x)
predictions = Dense(6, activation='softmax')(x)
model = Model( inputs = model.input, outputs=predictions)

model.compile(optimizer=Adam(learning_rate=0.0001),
       loss='categorical_crossentropy',
       metrics=['accuracy'])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %% [markdown]
# ## Set the model training mechanism

# %%
#model.layers[0].trainable=False
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# Used to store the model with the highest accuracy during the training process
checkpoint = ModelCheckpoint('MobileNetV2.h5', verbose=1,
                monitor='val_accuracy', save_best_only=True)

# dynamic learning rate
reduce_learning_rate= ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                    patience=5, mode='min', verbose=1,
                    min_learning_rate=1e-5)

# earlystop：If the model does not improve for a 10 consecutive epochs, then terminate the model training early
estop = EarlyStopping(monitor='val_loss', patience=10,verbose=1)

callbacks_list = [checkpoint, estop,reduce_learning_rate]

# Increase the penalty weight for data imbalance
class_weights = {i:value for i, value in enumerate(class_weights)}

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
history=model.fit_generator(train_generator,steps_per_epoch=steps_per_epoch_train,
                      epochs=50,
                      validation_data=valid_generator,
                      validation_steps = steps_per_epoch_val,
                      class_weight = class_weights,
                      callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 127/127 [==============================] - ETA: 0s - loss: 0.6399 - accuracy: 0.7596
# Epoch 1: val_accuracy improved from -inf to 0.49407, saving model to MobileNetV2.h5
# 127/127 [==============================] - 840s 6s/step - loss: 0.6399 - accuracy: 0.7596 - val_loss: 1.6674 - val_accuracy: 0.4941 - lr: 1.0000e-04
# Epoch 2/50
# 127/127 [==============================] - ETA: 0s - loss: 0.3023 - accuracy: 0.8863
# Epoch 2: val_accuracy did not improve from 0.49407
# 127/127 [==============================] - 40s 319ms/step - loss: 0.3023 - accuracy: 0.8863 - val_loss: 2.1788 - val_accuracy: 0.4051 - lr: 1.0000e-04
# Epoch 3/50
# 127/127 [==============================] - ETA: 0s - loss: 0.1935 - accuracy: 0.9313
# Epoch 3: val_accuracy did not improve from 0.49407
# 127/127 [==============================] - 41s 321ms/step - loss: 0.1935 - accuracy: 0.9313 - val_loss: 2.2243 - val_accuracy: 0.3340 - lr: 1.0000e-04
# Epoch 4/50
# 127/127 [==============================] - ETA: 0s - loss: 0.1765 - accuracy: 0.9416
# Epoch 4: val_accuracy improved from 0.49407 to 0.50593, saving model to MobileNetV2.h5
# 127/127 [==============================] - 41s 321ms/step - loss: 0.1765 - accuracy: 0.9416 - val_loss: 1.7084 - val_accuracy: 0.5059 - lr: 1.0000e-04
# Epoch 5/50
# 127/127 [==============================] - ETA: 0s - loss: 0.1305 - accuracy: 0.9609
# Epoch 5: val_accuracy improved from 0.50593 to 0.53953, saving model to MobileNetV2.h5
# 127/127 [==============================] - 42s 330ms/step - loss: 0.1305 - accuracy: 0.9609 - val_loss: 1.6868 - val_accuracy: 0.5395 - lr: 1.0000e-04
# Epoch 6/50
# 127/127 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9669
# Epoch 6: val_accuracy improved from 0.53953 to 0.59881, saving model to MobileNetV2.h5
# 127/127 [==============================] - 42s 331ms/step - loss: 0.1065 - accuracy: 0.9669 - val_loss: 1.5393 - val_accuracy: 0.5988 - lr: 1.0000e-04
# Epoch 7/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0595 - accuracy: 0.9782
# Epoch 7: val_accuracy improved from 0.59881 to 0.64229, saving model to MobileNetV2.h5
# 127/127 [==============================] - 41s 322ms/step - loss: 0.0595 - accuracy: 0.9782 - val_loss: 1.3367 - val_accuracy: 0.6423 - lr: 1.0000e-04
# Epoch 8/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 0.9773
# Epoch 8: val_accuracy improved from 0.64229 to 0.66206, saving model to MobileNetV2.h5
# 127/127 [==============================] - 42s 333ms/step - loss: 0.0599 - accuracy: 0.9773 - val_loss: 1.4954 - val_accuracy: 0.6621 - lr: 1.0000e-04
# Epoch 9/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9832
# Epoch 9: val_accuracy did not improve from 0.66206
# 127/127 [==============================] - 40s 318ms/step - loss: 0.0527 - accuracy: 0.9832 - val_loss: 4.0600 - val_accuracy: 0.4111 - lr: 1.0000e-04
# Epoch 10/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9827
# Epoch 10: val_accuracy did not improve from 0.66206
# 127/127 [==============================] - 42s 328ms/step - loss: 0.0613 - accuracy: 0.9827 - val_loss: 2.3305 - val_accuracy: 0.5632 - lr: 1.0000e-04
# Epoch 11/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9832
# Epoch 11: val_accuracy improved from 0.66206 to 0.74704, saving model to MobileNetV2.h5
# 127/127 [==============================] - 41s 326ms/step - loss: 0.0534 - accuracy: 0.9832 - val_loss: 1.4306 - val_accuracy: 0.7470 - lr: 1.0000e-04
# Epoch 12/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9871
# Epoch 12: val_accuracy did not improve from 0.74704
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 127/127 [==============================] - 41s 322ms/step - loss: 0.0319 - accuracy: 0.9871 - val_loss: 1.4595 - val_accuracy: 0.6344 - lr: 1.0000e-04
# Epoch 13/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0272 - accuracy: 0.9886
# Epoch 13: val_accuracy improved from 0.74704 to 0.78063, saving model to MobileNetV2.h5
# 127/127 [==============================] - 44s 343ms/step - loss: 0.0272 - accuracy: 0.9886 - val_loss: 0.7314 - val_accuracy: 0.7806 - lr: 5.0000e-05
# Epoch 14/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9911
# Epoch 14: val_accuracy did not improve from 0.78063
# 127/127 [==============================] - 41s 326ms/step - loss: 0.0224 - accuracy: 0.9911 - val_loss: 1.1278 - val_accuracy: 0.7470 - lr: 5.0000e-05
# Epoch 15/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9936
# Epoch 15: val_accuracy improved from 0.78063 to 0.85178, saving model to MobileNetV2.h5
# 127/127 [==============================] - 42s 328ms/step - loss: 0.0162 - accuracy: 0.9936 - val_loss: 0.4360 - val_accuracy: 0.8518 - lr: 5.0000e-05
# Epoch 16/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 0.9946
# Epoch 16: val_accuracy did not improve from 0.85178
# 127/127 [==============================] - 42s 327ms/step - loss: 0.0219 - accuracy: 0.9946 - val_loss: 0.4510 - val_accuracy: 0.8518 - lr: 5.0000e-05
# Epoch 17/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9946
# Epoch 17: val_accuracy improved from 0.85178 to 0.91897, saving model to MobileNetV2.h5
# 127/127 [==============================] - 42s 328ms/step - loss: 0.0184 - accuracy: 0.9946 - val_loss: 0.2519 - val_accuracy: 0.9190 - lr: 5.0000e-05
# Epoch 18/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9970
# Epoch 18: val_accuracy did not improve from 0.91897
# 127/127 [==============================] - 41s 324ms/step - loss: 0.0110 - accuracy: 0.9970 - val_loss: 0.2209 - val_accuracy: 0.9190 - lr: 5.0000e-05
# Epoch 19/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9990
# Epoch 19: val_accuracy improved from 0.91897 to 0.95850, saving model to MobileNetV2.h5
# 127/127 [==============================] - 42s 329ms/step - loss: 0.0088 - accuracy: 0.9990 - val_loss: 0.1212 - val_accuracy: 0.9585 - lr: 5.0000e-05
# Epoch 20/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9960
# Epoch 20: val_accuracy improved from 0.95850 to 0.97628, saving model to MobileNetV2.h5
# 127/127 [==============================] - 41s 322ms/step - loss: 0.0094 - accuracy: 0.9960 - val_loss: 0.0651 - val_accuracy: 0.9763 - lr: 5.0000e-05
# Epoch 21/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9965
# Epoch 21: val_accuracy improved from 0.97628 to 0.98221, saving model to MobileNetV2.h5
# 127/127 [==============================] - 42s 334ms/step - loss: 0.0084 - accuracy: 0.9965 - val_loss: 0.0681 - val_accuracy: 0.9822 - lr: 5.0000e-05
# Epoch 22/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.9951
# Epoch 22: val_accuracy improved from 0.98221 to 0.98419, saving model to MobileNetV2.h5
# 127/127 [==============================] - 41s 325ms/step - loss: 0.0164 - accuracy: 0.9951 - val_loss: 0.0403 - val_accuracy: 0.9842 - lr: 5.0000e-05
# Epoch 23/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9946
# Epoch 23: val_accuracy did not improve from 0.98419
# 127/127 [==============================] - 41s 324ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0527 - val_accuracy: 0.9783 - lr: 5.0000e-05
# Epoch 24/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9970
# Epoch 24: val_accuracy improved from 0.98419 to 0.98814, saving model to MobileNetV2.h5
# 127/127 [==============================] - 42s 327ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 0.0306 - val_accuracy: 0.9881 - lr: 5.0000e-05
# Epoch 25/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9955
# Epoch 25: val_accuracy did not improve from 0.98814
# 127/127 [==============================] - 43s 336ms/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 0.0213 - val_accuracy: 0.9881 - lr: 5.0000e-05
# Epoch 26/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9960
# Epoch 26: val_accuracy improved from 0.98814 to 0.99209, saving model to MobileNetV2.h5
# 127/127 [==============================] - 41s 325ms/step - loss: 0.0139 - accuracy: 0.9960 - val_loss: 0.0166 - val_accuracy: 0.9921 - lr: 5.0000e-05
# Epoch 27/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9980
# Epoch 27: val_accuracy improved from 0.99209 to 0.99407, saving model to MobileNetV2.h5
# 127/127 [==============================] - 41s 318ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.0196 - val_accuracy: 0.9941 - lr: 5.0000e-05
# Epoch 28/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9975
# Epoch 28: val_accuracy improved from 0.99407 to 0.99605, saving model to MobileNetV2.h5
# 127/127 [==============================] - 41s 322ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0140 - val_accuracy: 0.9960 - lr: 5.0000e-05
# Epoch 29/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9960
# Epoch 29: val_accuracy did not improve from 0.99605
# 127/127 [==============================] - 41s 320ms/step - loss: 0.0132 - accuracy: 0.9960 - val_loss: 0.0448 - val_accuracy: 0.9802 - lr: 5.0000e-05
# Epoch 30/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9990
# Epoch 30: val_accuracy did not improve from 0.99605
# 127/127 [==============================] - 41s 319ms/step - loss: 0.0055 - accuracy: 0.9990 - val_loss: 0.0185 - val_accuracy: 0.9921 - lr: 5.0000e-05
# Epoch 31/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9970
# Epoch 31: val_accuracy did not improve from 0.99605
# 127/127 [==============================] - 41s 324ms/step - loss: 0.0096 - accuracy: 0.9970 - val_loss: 0.0330 - val_accuracy: 0.9881 - lr: 5.0000e-05
# Epoch 32/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9995
# Epoch 32: val_accuracy did not improve from 0.99605
# 127/127 [==============================] - 42s 327ms/step - loss: 0.0042 - accuracy: 0.9995 - val_loss: 0.0253 - val_accuracy: 0.9901 - lr: 5.0000e-05
# Epoch 33/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9955
# Epoch 33: val_accuracy did not improve from 0.99605
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 127/127 [==============================] - 42s 335ms/step - loss: 0.0157 - accuracy: 0.9955 - val_loss: 0.0394 - val_accuracy: 0.9901 - lr: 5.0000e-05
# Epoch 34/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9955
# Epoch 34: val_accuracy did not improve from 0.99605
# 127/127 [==============================] - 41s 324ms/step - loss: 0.0110 - accuracy: 0.9955 - val_loss: 0.0283 - val_accuracy: 0.9941 - lr: 2.5000e-05
# Epoch 35/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9985
# Epoch 35: val_accuracy did not improve from 0.99605
# 127/127 [==============================] - 42s 328ms/step - loss: 0.0058 - accuracy: 0.9985 - val_loss: 0.0174 - val_accuracy: 0.9921 - lr: 2.5000e-05
# Epoch 36/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9985
# Epoch 36: val_accuracy improved from 0.99605 to 0.99802, saving model to MobileNetV2.h5
# 127/127 [==============================] - 42s 329ms/step - loss: 0.0100 - accuracy: 0.9985 - val_loss: 0.0110 - val_accuracy: 0.9980 - lr: 2.5000e-05
# Epoch 37/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9985
# Epoch 37: val_accuracy did not improve from 0.99802
# 127/127 [==============================] - 41s 324ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.0140 - val_accuracy: 0.9960 - lr: 2.5000e-05
# Epoch 38/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9975
# Epoch 38: val_accuracy did not improve from 0.99802
# 127/127 [==============================] - 41s 326ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.0212 - val_accuracy: 0.9921 - lr: 2.5000e-05
# Epoch 39/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9985
# Epoch 39: val_accuracy did not improve from 0.99802
# 127/127 [==============================] - 41s 324ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.0182 - val_accuracy: 0.9941 - lr: 2.5000e-05
# Epoch 40/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9980
# Epoch 40: val_accuracy did not improve from 0.99802
# 127/127 [==============================] - 41s 324ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.0166 - val_accuracy: 0.9941 - lr: 2.5000e-05
# Epoch 41/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9995
# Epoch 41: val_accuracy did not improve from 0.99802
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 127/127 [==============================] - 41s 321ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0164 - val_accuracy: 0.9960 - lr: 2.5000e-05
# Epoch 42/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.99802
# 127/127 [==============================] - 41s 323ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9921 - lr: 1.2500e-05
# Epoch 43/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9980
# Epoch 43: val_accuracy did not improve from 0.99802
# 127/127 [==============================] - 40s 310ms/step - loss: 0.0045 - accuracy: 0.9980 - val_loss: 0.0254 - val_accuracy: 0.9921 - lr: 1.2500e-05
# Epoch 44/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9985
# Epoch 44: val_accuracy did not improve from 0.99802
# 127/127 [==============================] - 40s 317ms/step - loss: 0.0031 - accuracy: 0.9985 - val_loss: 0.0207 - val_accuracy: 0.9901 - lr: 1.2500e-05
# Epoch 45/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9990
# Epoch 45: val_accuracy did not improve from 0.99802
# 127/127 [==============================] - 41s 321ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0213 - val_accuracy: 0.9901 - lr: 1.2500e-05
# Epoch 46/50
# 127/127 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9990
# Epoch 46: val_accuracy did not improve from 0.99802
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 127/127 [==============================] - 42s 330ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0146 - val_accuracy: 0.9941 - lr: 1.2500e-05
# Epoch 46: early stopping

# %% [markdown]
# ## Save and load model

# %%
from keras.models import load_model

model.save('/content/drive/My Drive/Colab Notebooks/AOI/aoi/MobileNetV2.h5')
MobileNetV2_saved = load_model('/content/drive/My Drive/Colab Notebooks/AOI/aoi/MobileNetV2.h5')

# %%
import matplotlib.pyplot as plt

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %% [markdown]
# ## Testing data prediction

# %%
test_list = pd.read_csv('/content/drive/My Drive/Colab Notebooks/AOI/aoi/test.csv',index_col=False)
test_list['Label'] = '7'

# %%
TEST_IMAGEPATH = '/content/drive/My Drive/Colab Notebooks/AOI/aoi/test_images/'

test_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)
test_generator = test_datagen.flow_from_dataframe( dataframe=test_list,
                directory = TEST_IMAGEPATH,
                x_col="ID",
                y_col="Label",
                target_size=img_shape,
                batch_size=batch_size,
                # class_mode='categorical',
                shuffle=False)
test_steps = len(test_generator)
# Out:
# Found 10142 validated image filenames belonging to 1 classes.

# %%
#The prediction will be a probability, so it needs to be converted
y_test_predprob = MobileNetV2_saved.predict(test_generator, steps = test_steps)
y_test_pred = y_test_predprob.argmax(-1)
y_test_pred
# Out:
# 634/634 [==============================] - 3370s 5s/step
# array([1, 2, 5, ..., 1, 3, 1])

# %%
test_list['Label'] = y_test_pred
test_list.to_csv('/content/drive/My Drive/Colab Notebooks/AOI/aoi/Mobile_submit.csv')

# %% [markdown]
# ## Final result
